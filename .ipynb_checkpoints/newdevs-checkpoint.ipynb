# %% [markdown]
# # Data Processing setup and library experimentation

# %%
from data_processing.data_wrangler import *

# %%
output_dict = DataLoad("G01V01P02_annotato.eaf","Data EAF\materials\G01\V01",['dstr','ORT','phr'])

# %%
output_dict
# Out:
# {'dstr':     ANNOTATION_ID                                     CVE_REF dstr  \
#  0           a1368  cveid_d673a93d-9f59-44c4-b1a1-6c7e214c6d6f  PRL
#  1           a1369  cveid_28867b92-92a6-4bb8-9ad8-665c02a73a98   SP
#  2           a1370  cveid_d673a93d-9f59-44c4-b1a1-6c7e214c6d6f  PRL
#  3           a1418  cveid_d673a93d-9f59-44c4-b1a1-6c7e214c6d6f  PRL
#  4           a1419  cveid_9ba87e8c-e6e7-45b2-9728-4310820223ce   FP
#  ..            ...                                         ...  ...
#  246         a2544  cveid_1ada0200-ccfb-4bf1-a447-f998e1f5f56e  REP
#  247         a2545  cveid_28867b92-92a6-4bb8-9ad8-665c02a73a98   SP
#  248         a2546  cveid_d673a93d-9f59-44c4-b1a1-6c7e214c6d6f  PRL
#  249         a2547  cveid_28867b92-92a6-4bb8-9ad8-665c02a73a98   SP
#  250         a2548  cveid_1ada0200-ccfb-4bf1-a447-f998e1f5f56e  REP
#
#       Begin Time  End Time   Nr
#  0          1127      1558    1
#  1          2482      2650    2
#  2          6800      7137    3
#  3          7748      8179    4
#  4          8180      8362    5
#  ..          ...       ...  ...
#  246      516460    516810  247
#  247      519693    519900  248
#  248      520321    520752  249
#  249      520752    520877  250
#  250      520878    521090  251
#
#  [251 rows x 6 columns],
#  'ort':      ANNOTATION_ID        ORT  Begin Time  End Time    Nr
#  0               a1     Allora         150       510     1
#  1               a2         ci         510       700     2
#  2               a3  siamo<oo>         700      1550     3
#  3               a4   spostati        1550      2482     4
#  4               a5       <sp>        2482      2650     5
#  ...            ...        ...         ...       ...   ...
#  1353         a1360       <sp>      519693    519900  1354
#  1354         a1361   alla<aa>      519900    520750  1355
#  1355         a1362       <sp>      520750    520878  1356
#  1356         a1363       alla      520878    521090  1357
#  1357         a1364  normalità      521090    521740  1358
#
#  [1358 rows x 5 columns],
#  'phr':    ANNOTATION_ID    phr  Begin Time  End Time  Nr
#  0          a2576   phr1         150     15650   1
#  1          a2577   phr2       15650     30616   2
#  2          a2578   phr3       30616     70581   3
#  3          a2579   phr4       70581     86380   4
#  4          a2580   phr5       86380    102905   5
#  5          a2581   phr6      102905    126897   6
#  6          a2582   phr7      126897    135126   7
#  7          a2583   phr8      135126    154194   8
#  8          a2584   phr9      154194    168570   9
#  9          a2585  phr10      168570    175190  10
#  10         a2586  phr11      175190    190204  11
#  11         a2587  phr12      190204    207232  12
#  12         a2588  phr13      207232    233708  13
#  13         a2589  phr14      233708    256212  14
#  14         a2590  phr15      256212    290570  15
#  15         a2591  phr16      290570    309420  16
#  16         a2592  phr17      309420    328340  17
#  17         a2593  phr18      328340    333962  18
#  18         a2594  phr19      333962    349450  19
#  19         a2595  phr20      349450    361342  20
#  20         a2596  phr21      361342    384364  21
#  21         a2597  phr22      384364    414275  22
#  22         a2598  phr23      414275    429540  23
#  23         a2599  phr24      429540    442375  24
#  24         a2600  phr25      442375    481300  25
#  25         a2601  phr26      481300    521740  26}

# %%
phr_wrangle.head()
# Out:
#   ANNOTATION_ID   phr  Begin Time  End Time  Nr
# 0         a2576  phr1         150     15650   1
# 1         a2577  phr2       15650     30616   2
# 2         a2578  phr3       30616     70581   3
# 3         a2579  phr4       70581     86380   4
# 4         a2580  phr5       86380    102905   5

# %%
data_wrangled = data_wrangle(output_dict)

# %%
#data_wrangled = data_wrangled[data_wrangled.isna()]

# %%
data_wrangled['Begin Time'] = data_wrangled['Begin Time'].astype('int64')
data_wrangled['End Time'] = data_wrangled['End Time'].astype('int64')
# Out:
#       0 ANNOTATION_ID  Begin Time  End Time  Nr       ORT  Duration
# 0   NaN            a1         150       510   1    Allora     360.0
# 1   NaN            a2         510       700   2        ci     190.0
# 2   NaN            a3         700      1127   3     siamo     427.0
# 3  <oo>           NaN        1127      1550   3     <PRL>     423.0
# 4   NaN            a4        1550      2482   4  spostati     932.0

# %%
display(data_wrangled.head())
# Out:
#       0 ANNOTATION_ID  Begin Time  End Time  Nr       ORT  Duration
# 0   NaN            a1         150       510   1    Allora     360.0
# 1   NaN            a2         510       700   2        ci     190.0
# 2   NaN            a3         700      1127   3     siamo     427.0
# 3  <oo>           NaN        1127      1550   3     <PRL>     423.0
# 4   NaN            a4        1550      2482   4  spostati     932.0

# %%
data_all = pd.merge_asof(data_wrangled,phr_wrangle,on='Begin Time')

# %%
data_all[data_all.phr=='phr1']
# Out:
#        0 ANNOTATION_ID_x  Begin Time  End Time_x  Nr_x            ORT  \
# 0    NaN              a1         150         510     1         Allora
# 1    NaN              a2         510         700     2             ci
# 2    NaN              a3         700        1127     3          siamo
# 3   <oo>             NaN        1127        1550     3          <PRL>
# 4    NaN              a4        1550        2482     4       spostati
# 5    NaN              a5        2482        2650     5           <sp>
# 6    NaN              a6        2650        2930     6          dalla
# 7    NaN              a7        2930        3070     7           <sp>
# 8    NaN              a8        3070        3480     8         Chiesa
# 9    NaN              a9        3480        3800     9        abbiamo
# 10   NaN             a10        3800        4530    10   attraversato
# 11   NaN             a11        4530        4630    11             il
# 12   NaN             a12        4630        5090    12       chiostro
# 13   NaN             a13        5090        5190    13            dei
# 14   NaN             a14        5190        6180    14    procuratori
# 15   NaN             a15        6180        6610    15  <inspiration>
# 16   NaN             a16        6610        7140    16            che
# 17   NaN             a17        7140        8180    17          erano
# 18   NaN             a18        8180        8362    18         <ehm>
# 19   NaN             a19        8362        8710    19        insomma
# 20   NaN             a20        8710        8935    20          delle
# 21   NaN             a21        8935        9370    21         figure
# 22   NaN             a22        9370        9970    22     abbastanza
# 23   NaN             a23        9970       10960    23     importanti
# 24   NaN             a24       10960       11280    24            per
# 25   NaN             a25       11280       11420    25           <sp>
# 26   NaN             a26       11420       12022    26          <ehm>
# 27   NaN             a27       12022       12130    27              e
# 28   NaN             a28       12130       13020    28     funzionali
# 29   NaN             a29       13020       13360    29           alla
# 30   NaN             a30       13360       14070    30           vita
# 31   NaN             a31       14070       14431    31       alla v+/
# 32   NaN             a32       14431       14652    32           alla
# 33   NaN             a33       14652       14840    33           vita
# 34   NaN             a34       14840       15000    34          della
# 35   NaN             a35       15000       15650    35        Certosa
#
#     Duration ANNOTATION_ID_y   phr  End Time_y  Nr_y
# 0      360.0           a2576  phr1       15650     1
# 1      190.0           a2576  phr1       15650     1
# 2      427.0           a2576  phr1       15650     1
# 3      423.0           a2576  phr1       15650     1
# 4      932.0           a2576  phr1       15650     1
# 5      168.0           a2576  phr1       15650     1
# 6      280.0           a2576  phr1       15650     1
# 7      140.0           a2576  phr1       15650     1
# 8      410.0           a2576  phr1       15650     1
# 9      320.0           a2576  phr1       15650     1
# 10     730.0           a2576  phr1       15650     1
# 11     100.0           a2576  phr1       15650     1
# 12     460.0           a2576  phr1       15650     1
# 13     100.0           a2576  phr1       15650     1
# 14     990.0           a2576  phr1       15650     1
# 15     430.0           a2576  phr1       15650     1
# 16     530.0           a2576  phr1       15650     1
# 17    1040.0           a2576  phr1       15650     1
# 18     182.0           a2576  phr1       15650     1
# 19     348.0           a2576  phr1       15650     1
# 20     225.0           a2576  phr1       15650     1
# 21     435.0           a2576  phr1       15650     1
# 22     600.0           a2576  phr1       15650     1
# 23     990.0           a2576  phr1       15650     1
# 24     320.0           a2576  phr1       15650     1
# 25     140.0           a2576  phr1       15650     1
# 26     602.0           a2576  phr1       15650     1
# 27     108.0           a2576  phr1       15650     1
# 28     890.0           a2576  phr1       15650     1
# 29     340.0           a2576  phr1       15650     1
# 30     710.0           a2576  phr1       15650     1
# 31     361.0           a2576  phr1       15650     1
# 32     221.0           a2576  phr1       15650     1
# 33     188.0           a2576  phr1       15650     1
# 34     160.0           a2576  phr1       15650     1
# 35     650.0           a2576  phr1       15650     1

# %%
data_all[data_all.phr=='phr26']
# Out:
#         0 ANNOTATION_ID_x  Begin Time  End Time_x  Nr_x        ORT  Duration  \
# 1263  NaN           a1261      481300      482086  1256   <breath>     786.0
# 1264  NaN           a1262      482086      482300  1257       bene     214.0
# 1265  NaN           a1263      482300      483040  1258     questa     740.0
# 1266  NaN           a1264      483040      483140  1259         in     100.0
# 1267  NaN           a1265      483140      483440  1260     questo     300.0
# ...   ...             ...         ...         ...   ...        ...       ...
# 1361  NaN           a1360      519693      519900  1354       <sp>     207.0
# 1362  NaN           a1361      519900      520750  1355       alla     850.0
# 1363  NaN           a1362      520750      520878  1356       <sp>     128.0
# 1364  NaN           a1363      520878      521090  1357       alla     212.0
# 1365  NaN           a1364      521090      521740  1358  normalità     650.0
#
#      ANNOTATION_ID_y    phr  End Time_y  Nr_y
# 1263           a2601  phr26      521740    26
# 1264           a2601  phr26      521740    26
# 1265           a2601  phr26      521740    26
# 1266           a2601  phr26      521740    26
# 1267           a2601  phr26      521740    26
# ...              ...    ...         ...   ...
# 1361           a2601  phr26      521740    26
# 1362           a2601  phr26      521740    26
# 1363           a2601  phr26      521740    26
# 1364           a2601  phr26      521740    26
# 1365           a2601  phr26      521740    26
#
# [103 rows x 11 columns]

# %%
display(data_wrangled.tail())
# Out:
#         0 ANNOTATION_ID  Begin Time  End Time    Nr        ORT  Duration
# 1361  NaN         a1360      519693    519900  1354       <sp>     207.0
# 1362  NaN         a1361      519900    520750  1355       alla     850.0
# 1363  NaN         a1362      520750    520878  1356       <sp>     128.0
# 1364  NaN         a1363      520878    521090  1357       alla     212.0
# 1365  NaN         a1364      521090    521740  1358  normalità     650.0

# %%
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1366 entries, 0 to 1365
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   0                8 non-null      object
#  1   ANNOTATION_ID_x  1358 non-null   object
#  2   Begin Time       1366 non-null   int64
#  3   End Time_x       1366 non-null   int64
#  4   Nr_x             1366 non-null   int32
#  5   ORT              1366 non-null   object
#  6   Duration         1366 non-null   float64
#  7   ANNOTATION_ID_y  1366 non-null   object
#  8   phr              1366 non-null   object
#  9   End Time_y       1366 non-null   int64
#  10  Nr_y             1366 non-null   int64
# dtypes: float64(1), int32(1), int64(4), object(5)
# memory usage: 122.7+ KB

# %%
for el in range(5):
    print(el)

# %% [markdown]
# # Wav files!

# %%
# !pip install samplerate
# Out:
# Collecting samplerate
#   Downloading samplerate-0.1.0-py2.py3-none-any.whl (4.0 MB)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\hellf\.conda\envs\tacotron2\lib\site-packages (from samplerate) (1.14.5)
# Requirement already satisfied: numpy in c:\users\hellf\.conda\envs\tacotron2\lib\site-packages (from samplerate) (1.19.5)
# Requirement already satisfied: pycparser in c:\users\hellf\.conda\envs\tacotron2\lib\site-packages (from cffi>=1.0.0->samplerate) (2.20)
# Installing collected packages: samplerate
# Successfully installed samplerate-0.1.0

# %%
from scipy.io import wavfile
import pandas as pd
import numpy as np
import re
from data_processing.data_wrangler import *
import os
#from scipy.signal import resample #things tried not working
#import samplerate #things tried not working

# %%
def folder_reader(file_path,config_file_path='config_file.txt',text_file=True,token=True,research_keys=['dstr', 'ORT'],debug=False):

    with open(config_file_path,'r+') as file:
        files_list = file.read().split('\n')

    wav_reference = [re.sub(r'_.*',"",el) for el in files_list]
    df = []
    for _ in range(len(files_list)):

        out_filename = files_list[_]

        if debug:

            print("Debugging, the filename is: ",out_filename)

        if text_file:

            out_dict = DataLoad(out_filename, file_path, keys_to_search=research_keys, text_file = True)

        else:

            out_filename = out_filename + ".eaf"
            out_dict = DataLoad(out_filename, file_path, keys_to_search=research_keys, text_file=False)

        if token:

            ort_data_new = data_wrangle(out_dict, token=True)

        else:

            ort_data_new = data_wrangle(out_dict, token=False)

        ort_data_new['wav_reference'] = wav_reference[_] + '.wav'
        ort_data_new = ort_data_new.drop(0,axis=1)

        try:
            ort_data_new['Begin Time'] = ort_data_new['Begin Time'].astype('int64')
            ort_data_new['End Time'] = ort_data_new['End Time'].astype('int64')
        except:
            raise Exception('Error in data, couldn\'t convert "Begin Time" and "End Time" format to int 64.\n\n There are %d missing values in "Begon Time" and %d in "End Time"\n This is the traceback:\n\n%s'%(ort_data_new['Begin Time'].isna().sum(),ort_data_new['End Time'].isna().sum(),sys.exc_info()[1]))
        #if 'phr' in research_keys:
        #    ort_data_new = data_all = pd.merge_asof(ort_data_new,out_dict['phr'],on='Begin Time',suffixes = ['','_phr'])
        df.append(ort_data_new)

    df = pd.concat(df)

    return df, out_dict

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hellf\\OneDrive - Università di Napoli Federico II\\Tesi'

# %%
data, out_dict = folder_reader("\\Data EAF\\materials\\G01\\V01",research_keys=['dstr', 'ORT','phr'],text_file = False)

# %%
data
# Out:
#      ANNOTATION_ID  Begin Time  End Time    Nr            ORT  Duration  \
# 0               a1         150       510     1         Allora     360.0
# 1               a2         510       700     2             ci     190.0
# 2               a3         700      1127     3          siamo     427.0
# 3              NaN        1127      1550     3          <PRL>     423.0
# 4               a4        1550      2482     4       spostati     932.0
# ...            ...         ...       ...   ...            ...       ...
# 1504         a1501      603908    604521  1502        pittore     613.0
# 1505         a1502      604521    605052  1503           così     531.0
# 1506         a1503      605052    605289  1504  <inspiration>     237.0
# 1507         a1504      605289    605634  1505          <eeh>     345.0
# 1508         a1505      605634    606740  1506  straordinario    1106.0
#
#       wav_reference
# 0     G01V01P02.wav
# 1     G01V01P02.wav
# 2     G01V01P02.wav
# 3     G01V01P02.wav
# 4     G01V01P02.wav
# ...             ...
# 1504  G01V01P06.wav
# 1505  G01V01P06.wav
# 1506  G01V01P06.wav
# 1507  G01V01P06.wav
# 1508  G01V01P06.wav
#
# [5578 rows x 7 columns]

# %%
out_dict['phr'].phr.value_counts().sum()
# Out:
# 79

# %%
len(os.listdir(os.getcwd()+os.path.sep+os.path.join("Data EAF","materials","G01","training_data","wavs")))
# Out:
# 303

# %%
with open(os.getcwd()+os.path.sep+os.path.join("Data EAF","materials","G01","training_data","training_data.txt"),'r+') as file:
    tr_data = file.read().split("\n")
print(tr_data.__len__())
# Out:
# 303

# %%
def wav_reader(int_min = 15650,int_max = 30616,filename = 'G01V01P02.wav',out_name = 'prova.wav',filepath='Data EAF\\materials\\G01\\V01',out_path='Data EAF\\materials\\G01\\training_data\\wavs'):
    file_name = os.path.join('.',*filepath.split(os.path.sep),filename)
    audio_data = wavfile.read(file_name)
    phrase = audio_data[1]
    rate = audio_data[0]
    time = np.arange(1.,phrase.shape[0]/rate*1000+1,1/(rate/1000))
    out_file = os.path.join(*out_path.split(os.path.sep),out_name)
    if int_min-200 >=0:
        wavfile.write(out_file,rate,phrase[np.argmax(time[np.logical_and(time >= 0, time <= int_min-200)]):np.argmax(time[np.logical_and(time >= 0, time <= int_max+200)])])
    else:
        wavfile.write(out_file,rate,phrase[np.argmax(time[np.logical_and(time >= 0, time <= int_min+1)]):np.argmax(time[np.logical_and(time >= 0, time <= int_max+200)])])
        
#wavfile.write('prova.wav',rate,phrase[int((100+2)*44.12197646337256):int((15650+2)*44.12197646337256)])

# %%
df = pd.read_csv('.\\preprocessing_results\\trial.csv')

# %%
df.tail()
# Out:
#      ANNOTATION_ID  Begin Time  End Time    Nr            ORT  Duration  \
# 5573         a1501      603908    604521  1502        pittore     613.0
# 5574         a1502      604521    605052  1503           così     531.0
# 5575         a1503      605052    605289  1504  <inspiration>     237.0
# 5576         a1504      605289    605634  1505          <eeh>     345.0
# 5577         a1505      605634    606740  1506  straordinario    1106.0
#
#       wav_reference ANNOTATION_ID_phr       phr  End Time_phr  Nr_phr
# 5573  G01V01P06.wav             a9530  phr122bc        606740      79
# 5574  G01V01P06.wav             a9530  phr122bc        606740      79
# 5575  G01V01P06.wav             a9530  phr122bc        606740      79
# 5576  G01V01P06.wav             a9530  phr122bc        606740      79
# 5577  G01V01P06.wav             a9530  phr122bc        606740      79

# %%
df.phr.value_counts()
# Out:
# phr16b    31
# phr39     31
# phr50     31
# phr13b    30
# phr13e    30
#           ..
# phr22c     8
# phr29b     7
# phr79b     6
# phr26f     5
# phr45b     3
# Name: phr, Length: 302, dtype: int64

# %%
df.loc[df.phr=='phr1','wav_reference'].str.replace('.wav','').iloc[0]+'phr1'+'.wav'
# Out:
# 'G01V01P02phr1.wav'

# %%
'wavs/'+' '.join(df.loc[df.phr=='phr1','ORT'].to_list())
# Out:
# 'wavs/Allora ci siamo <PRL> spostati <sp> dalla <sp> Chiesa abbiamo attraversato il chiostro dei procuratori <inspiration>'

# %%
#%debug
written_annot = []
for phr in df.phr.unique():
    phrase_start = df.loc[df.phr==phr,'Begin Time'].min()
    phrase_end = df.loc[df.phr==phr,'End Time'].max()
    input_file = df.loc[df.phr==phr,'wav_reference'].iloc[0]
    out_file_name = df.loc[df.phr==phr,'wav_reference'].str.replace('.wav','').iloc[0]+phr+'.wav'
    wav_reader(phrase_start,phrase_end,input_file,out_file_name)
    written_annot.append('wavs/'+df.loc[df.phr==phr,'wav_reference'].str.replace('.wav','').iloc[0]+phr+'.wav'+'|'+' '.join(df.loc[df.phr==phr,'ORT'].to_list()))
# Out:
# c:\users\hellf\.conda\envs\tacotron2\lib\site-packages\scipy\io\wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
written_annot = [el.replace('à',"a'").replace('è',"e'").replace('ì',"i'").replace('ò',"o'").replace('ù',"u'").encode("utf8") for el in written_annot]

# %%
written_annot = [el.decode() for el in written_annot]

# %%
df_all = pd.DataFrame([{'file':el.split('|')[0],'text':el.split('|')[1]} for el in written_annot])
df_all.text = df_all.text + '.'
display(df_all.head())
# Out:
#                       file                                               text
# 0   wavs/G01V01P02phr1.wav  Allora ci siamo <PRL> spostati <sp> dalla <sp>...
# 1  wavs/G01V01P02phr1b.wav  che erano <ehm>  insomma delle figure abbastan...
# 2  wavs/G01V01P02phr1c.wav  e funzionali alla vita alla v+/ alla vita dell...
# 3   wavs/G01V01P02phr2.wav  <inspiration> cioe' ovvero erano coloro che si...
# 4  wavs/G01V01P02phr2b.wav  <sp> di tutto cio' che concerne la vita <inspi...

# %%
os.listdir("Data EAF")
# Out:
# ['materials', 'Output WAV', 'Training Data - EAF']

# %%
df_all.to_csv('Data EAF\\materials\\G01\\training_data\\training_data.txt',sep='|',index=False,header=False,encoding='utf-8')

# %%
#with open('Data EAF\\materials\\G01\\training_data\\training_data.txt','w+') as file:
#    file.write('\n'.join(written_annot)+'.',)

# %%
df[df.phr==phr].head()
# Out:
#      ANNOTATION_ID  Begin Time  End Time  Nr         ORT  Duration  \
# 3018            a1           0       130   1          Vi     130.0
# 3019            a2         130       421   2          ho     291.0
# 3020            a3         421       956   3  anticipato     535.0
# 3021            a4         956      1840   4  all'inizio     884.0
# 3022            a5        1840      1993   5        <sp>     153.0
#
#       wav_reference ANNOTATION_ID_phr    phr  End Time_phr  Nr_phr
# 3018  G01V01P05.wav             a6741  phr65          9839       1
# 3019  G01V01P05.wav             a6741  phr65          9839       1
# 3020  G01V01P05.wav             a6741  phr65          9839       1
# 3021  G01V01P05.wav             a6741  phr65          9839       1
# 3022  G01V01P05.wav             a6741  phr65          9839       1

# %%
print(phrase_start,phrase_end)
# Out:
# 0 9839

# %% [markdown]
# # Old elements

# %%
#15650*44.12197646337256
# Out:
# 690508.9316517806

# %%
#import numpy as np
##time = np.linspace(0.,phrase.shape[0]/rate,phrase.shape[0])
#time = np.arange(1.,phrase.shape[0]/rate*1000+1,1/(rate/1000))
##time *= 1000

# %%
#time = time.astype('int64') #provo rendendolo integer, ma è troppo basso, vado al livello millisecond direttamente

# %%
#print(rate,phrase.shape,phrase.shape[0]/522000)
# Out:
# 44100 (23020200,) 44.1

# %%
#import matplotlib.pyplot as plt
#plt.plot(time, phrase)

# %%
#np.argmax(time[np.logical_and(time>=0,time<=15650+10)])
# Out:
# 690561

# %%
#time.shape
# Out:
# (23020200,)

# %%
#phrase.shape[0]/rate,phrase.shape[0]*1000+1
# Out:
# (522.0, 23020200001)

# %%
#img = np.random.randint(0,100,size=(3,48,48))
